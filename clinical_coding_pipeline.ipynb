# %% [markdown]
# # Clinical Coding Pipeline — Stage Notebooks
#
# Run stages **in order**. Configure in `pipeline_config.py`:
#
# ```python
# TEST_MODE = True          # 1 patient smoke test
# LLM_PROVIDER = "ollama"        # or "openrouter" or "api"
# # OpenRouter: export OPENROUTER_API_KEY=sk-or-...
# ```
#
# | Stage | Notebook | Description | Output |
# |-------|----------|-------------|--------|
# | **1** | `stage_01_cohort_selection.ipynb` | Choose patients (ICD-10 + notes) | `data/.../cohort/` |
# | **2** | `stage_02_information_extraction.ipynb` | Information extraction (Ollama or API) | `data/.../stage_02_.../` |
# | **3** | `stage_03_symptom_tree.ipynb` | Symptom trees (Ollama or API) | `data/.../stage_03_.../` |
# | **4** | `stage_04_export_patient_records.ipynb` | Per-patient folder export | `patient_records/` |
#
# ```bash
# pip install pandas requests jupyter
# # Ollama: ollama serve && ollama pull qwen2.5:7b
# # API: export OPENAI_API_KEY=sk-...
# jupyter notebook notebooks/stage_01_cohort_selection.ipynb
# ```
