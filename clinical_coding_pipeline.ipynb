# %% [markdown]
# # Clinical Coding Pipeline — Stage Notebooks
#
# 1. **`notebooks/00_settings.ipynb`** — edit TEST_MODE, MIMIC path, LLM provider
# 2. Run stages **in order**:
#
# | Stage | Notebook | Output |
# |-------|----------|--------|
# | 0 | `00_settings.ipynb` | `settings.json` |
# | 1 | `stage_01_cohort_selection.ipynb` | `data/cohort/` |
# | 2 | `stage_02_information_extraction.ipynb` | `data/stage_02_.../` |
# | 3 | `stage_03_symptom_tree.ipynb` | `data/stage_03_.../` |
# | 4 | `stage_04_export_patient_records.ipynb` | `patient_records/` |
#
# Shared code: **`notebooks/pipeline.py`** (single module — no root `.py` files).
#
# See [README.md](README.md) for full stage details.
